# %%
import seaborn as sns
import warnings
import numpy as np
import pandas as pd
warnings.filterwarnings('ignore')
import mlflow
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error as RMSE 
import xgboost as xgb

# %%
from hyperopt import STATUS_OK, Trials, fmin, hp, tpe, space_eval 
from hyperopt.early_stop import no_progress_loss

# %%
mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("XGBoostRegressor")
# Out:
# <Experiment: artifact_location='/workspaces/MLOps/01-intro/mlruns/2', creation_time=1727873771114, experiment_id='2', last_update_time=1727873771114, lifecycle_stage='active', name='XGBoostRegressor', tags={}>

# %%
df = pd.read_parquet('https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2021-01.parquet')

# %%
df
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0             2  2021-01-01 00:15:56   2021-01-01 00:19:52                  N
# 1             2  2021-01-01 00:25:59   2021-01-01 00:34:44                  N
# 2             2  2021-01-01 00:45:57   2021-01-01 00:51:55                  N
# 3             2  2020-12-31 23:57:51   2021-01-01 00:04:56                  N
# 4             2  2021-01-01 00:16:36   2021-01-01 00:16:40                  N
# ...         ...                  ...                   ...                ...
# 76513         2  2021-01-31 21:38:00   2021-01-31 22:16:00               None
# 76514         2  2021-01-31 22:43:00   2021-01-31 23:21:00               None
# 76515         2  2021-01-31 22:16:00   2021-01-31 22:27:00               None
# 76516         2  2021-01-31 23:10:00   2021-01-31 23:37:00               None
# 76517         2  2021-01-31 23:25:00   2021-01-31 23:35:00               None
#
#        RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0             1.0            43           151              1.0           1.01
# 1             1.0           166           239              1.0           2.53
# 2             1.0            41            42              1.0           1.12
# 3             1.0           168            75              1.0           1.99
# 4             2.0           265           265              3.0           0.00
# ...           ...           ...           ...              ...            ...
# 76513         NaN            81            90              NaN          17.63
# 76514         NaN            35           213              NaN          18.36
# 76515         NaN            74            69              NaN           2.50
# 76516         NaN           168           215              NaN          14.48
# 76517         NaN           119           244              NaN           1.81
#
#        fare_amount  extra  mta_tax  tip_amount  tolls_amount ehail_fee  \
# 0             5.50   0.50      0.5        0.00          0.00      None
# 1            10.00   0.50      0.5        2.81          0.00      None
# 2             6.00   0.50      0.5        1.00          0.00      None
# 3             8.00   0.50      0.5        0.00          0.00      None
# 4           -52.00   0.00     -0.5        0.00          0.00      None
# ...            ...    ...      ...         ...           ...       ...
# 76513        56.23   2.75      0.0        0.00          6.12      None
# 76514        46.66   0.00      0.0       12.20          6.12      None
# 76515        18.95   2.75      0.0        0.00          0.00      None
# 76516        48.87   2.75      0.0        0.00          6.12      None
# 76517        15.45   2.75      0.0        0.00          0.00      None
#
#        improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                        0.3          6.80           2.0        1.0
# 1                        0.3         16.86           1.0        1.0
# 2                        0.3          8.30           1.0        1.0
# 3                        0.3          9.30           2.0        1.0
# 4                       -0.3        -52.80           3.0        1.0
# ...                      ...           ...           ...        ...
# 76513                    0.3         65.40           NaN        NaN
# 76514                    0.3         65.28           NaN        NaN
# 76515                    0.3         22.00           NaN        NaN
# 76516                    0.3         58.04           NaN        NaN
# 76517                    0.3         18.50           NaN        NaN
#
#        congestion_surcharge
# 0                      0.00
# 1                      2.75
# 2                      0.00
# 3                      0.00
# 4                      0.00
# ...                     ...
# 76513                   NaN
# 76514                   NaN
# 76515                   NaN
# 76516                   NaN
# 76517                   NaN
#
# [76518 rows x 20 columns]

# %%
df.dtypes
# Out:
# VendorID                          int64
# lpep_pickup_datetime     datetime64[us]
# lpep_dropoff_datetime    datetime64[us]
# store_and_fwd_flag               object
# RatecodeID                      float64
# PULocationID                      int64
# DOLocationID                      int64
# passenger_count                 float64
# trip_distance                   float64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# ehail_fee                        object
# improvement_surcharge           float64
# total_amount                    float64
# payment_type                    float64
# trip_type                       float64
# congestion_surcharge            float64
# dtype: object

# %%
df['duration'] = df['lpep_dropoff_datetime'] - df['lpep_pickup_datetime']

# %%
df.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2021-01-01 00:15:56   2021-01-01 00:19:52                  N
# 1         2  2021-01-01 00:25:59   2021-01-01 00:34:44                  N
# 2         2  2021-01-01 00:45:57   2021-01-01 00:51:55                  N
# 3         2  2020-12-31 23:57:51   2021-01-01 00:04:56                  N
# 4         2  2021-01-01 00:16:36   2021-01-01 00:16:40                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0            43           151              1.0           1.01
# 1         1.0           166           239              1.0           2.53
# 2         1.0            41            42              1.0           1.12
# 3         1.0           168            75              1.0           1.99
# 4         2.0           265           265              3.0           0.00
#
#    fare_amount  ...  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 0          5.5  ...      0.5        0.00           0.0       None
# 1         10.0  ...      0.5        2.81           0.0       None
# 2          6.0  ...      0.5        1.00           0.0       None
# 3          8.0  ...      0.5        0.00           0.0       None
# 4        -52.0  ...     -0.5        0.00           0.0       None
#
#   improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                   0.3          6.80           2.0        1.0
# 1                   0.3         16.86           1.0        1.0
# 2                   0.3          8.30           1.0        1.0
# 3                   0.3          9.30           2.0        1.0
# 4                  -0.3        -52.80           3.0        1.0
#
#    congestion_surcharge        duration
# 0                  0.00 0 days 00:03:56
# 1                  2.75 0 days 00:08:45
# 2                  0.00 0 days 00:05:58
# 3                  0.00 0 days 00:07:05
# 4                  0.00 0 days 00:00:04
#
# [5 rows x 21 columns]

# %%
df.duration = df.duration.apply(lambda ld : ld.total_seconds()/60)

# %%
df.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2021-01-01 00:15:56   2021-01-01 00:19:52                  N
# 1         2  2021-01-01 00:25:59   2021-01-01 00:34:44                  N
# 2         2  2021-01-01 00:45:57   2021-01-01 00:51:55                  N
# 3         2  2020-12-31 23:57:51   2021-01-01 00:04:56                  N
# 4         2  2021-01-01 00:16:36   2021-01-01 00:16:40                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0            43           151              1.0           1.01
# 1         1.0           166           239              1.0           2.53
# 2         1.0            41            42              1.0           1.12
# 3         1.0           168            75              1.0           1.99
# 4         2.0           265           265              3.0           0.00
#
#    fare_amount  ...  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 0          5.5  ...      0.5        0.00           0.0       None
# 1         10.0  ...      0.5        2.81           0.0       None
# 2          6.0  ...      0.5        1.00           0.0       None
# 3          8.0  ...      0.5        0.00           0.0       None
# 4        -52.0  ...     -0.5        0.00           0.0       None
#
#   improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                   0.3          6.80           2.0        1.0
# 1                   0.3         16.86           1.0        1.0
# 2                   0.3          8.30           1.0        1.0
# 3                   0.3          9.30           2.0        1.0
# 4                  -0.3        -52.80           3.0        1.0
#
#    congestion_surcharge  duration
# 0                  0.00  3.933333
# 1                  2.75  8.750000
# 2                  0.00  5.966667
# 3                  0.00  7.083333
# 4                  0.00  0.066667
#
# [5 rows x 21 columns]

# %%
df.duration.describe()
# Out:
# count    76518.000000
# mean        19.927896
# std         59.338594
# min          0.000000
# 25%          8.000000
# 50%         13.883333
# 75%         23.000000
# max       1439.600000
# Name: duration, dtype: float64

# %%
df.duration.describe(percentiles=[0.95,0.98,0.99])
# Out:
# count    76518.000000
# mean        19.927896
# std         59.338594
# min          0.000000
# 50%         13.883333
# 95%         44.000000
# 98%         56.000000
# 99%         67.158167
# max       1439.600000
# Name: duration, dtype: float64

# %% [markdown]
# #### **98% 56.000000 : Most of the trip (98%) duration is within an Hour**
# #### we should focus in that range only

# %%
df = df[(df.duration >= 1.0) & (df.duration <= 60.0)]

# %%
df
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0             2  2021-01-01 00:15:56   2021-01-01 00:19:52                  N
# 1             2  2021-01-01 00:25:59   2021-01-01 00:34:44                  N
# 2             2  2021-01-01 00:45:57   2021-01-01 00:51:55                  N
# 3             2  2020-12-31 23:57:51   2021-01-01 00:04:56                  N
# 7             2  2021-01-01 00:26:31   2021-01-01 00:28:50                  N
# ...         ...                  ...                   ...                ...
# 76513         2  2021-01-31 21:38:00   2021-01-31 22:16:00               None
# 76514         2  2021-01-31 22:43:00   2021-01-31 23:21:00               None
# 76515         2  2021-01-31 22:16:00   2021-01-31 22:27:00               None
# 76516         2  2021-01-31 23:10:00   2021-01-31 23:37:00               None
# 76517         2  2021-01-31 23:25:00   2021-01-31 23:35:00               None
#
#        RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0             1.0            43           151              1.0           1.01
# 1             1.0           166           239              1.0           2.53
# 2             1.0            41            42              1.0           1.12
# 3             1.0           168            75              1.0           1.99
# 7             1.0            75            75              6.0           0.45
# ...           ...           ...           ...              ...            ...
# 76513         NaN            81            90              NaN          17.63
# 76514         NaN            35           213              NaN          18.36
# 76515         NaN            74            69              NaN           2.50
# 76516         NaN           168           215              NaN          14.48
# 76517         NaN           119           244              NaN           1.81
#
#        fare_amount  ...  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 0             5.50  ...      0.5        0.00          0.00       None
# 1            10.00  ...      0.5        2.81          0.00       None
# 2             6.00  ...      0.5        1.00          0.00       None
# 3             8.00  ...      0.5        0.00          0.00       None
# 7             3.50  ...      0.5        0.96          0.00       None
# ...            ...  ...      ...         ...           ...        ...
# 76513        56.23  ...      0.0        0.00          6.12       None
# 76514        46.66  ...      0.0       12.20          6.12       None
# 76515        18.95  ...      0.0        0.00          0.00       None
# 76516        48.87  ...      0.0        0.00          6.12       None
# 76517        15.45  ...      0.0        0.00          0.00       None
#
#       improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                       0.3          6.80           2.0        1.0
# 1                       0.3         16.86           1.0        1.0
# 2                       0.3          8.30           1.0        1.0
# 3                       0.3          9.30           2.0        1.0
# 7                       0.3          5.76           1.0        1.0
# ...                     ...           ...           ...        ...
# 76513                   0.3         65.40           NaN        NaN
# 76514                   0.3         65.28           NaN        NaN
# 76515                   0.3         22.00           NaN        NaN
# 76516                   0.3         58.04           NaN        NaN
# 76517                   0.3         18.50           NaN        NaN
#
#        congestion_surcharge   duration
# 0                      0.00   3.933333
# 1                      2.75   8.750000
# 2                      0.00   5.966667
# 3                      0.00   7.083333
# 7                      0.00   2.316667
# ...                     ...        ...
# 76513                   NaN  38.000000
# 76514                   NaN  38.000000
# 76515                   NaN  11.000000
# 76516                   NaN  27.000000
# 76517                   NaN  10.000000
#
# [73908 rows x 21 columns]

# %%
df.duration.mean()
# Out:
# np.float64(16.852578430841948)

# %%
sns.distplot(df.duration)
# Out:
# <Axes: xlabel='duration', ylabel='Density'>

# %%
df.isna().sum()
# Out:
# VendorID                     0
# lpep_pickup_datetime         0
# lpep_dropoff_datetime        0
# store_and_fwd_flag       35733
# RatecodeID               35733
# PULocationID                 0
# DOLocationID                 0
# passenger_count          35733
# trip_distance                0
# fare_amount                  0
# extra                        0
# mta_tax                      0
# tip_amount                   0
# tolls_amount                 0
# ehail_fee                73908
# improvement_surcharge        0
# total_amount                 0
# payment_type             35733
# trip_type                35733
# congestion_surcharge     35733
# duration                     0
# dtype: int64

# %%
df.drop(columns=['store_and_fwd_flag','RatecodeID','passenger_count','ehail_fee','payment_type','trip_type','congestion_surcharge'],inplace=True)

# %%
df.isna().sum()
# Out:
# VendorID                 0
# lpep_pickup_datetime     0
# lpep_dropoff_datetime    0
# PULocationID             0
# DOLocationID             0
# trip_distance            0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# duration                 0
# dtype: int64

# %%
df.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime  PULocationID  \
# 0         2  2021-01-01 00:15:56   2021-01-01 00:19:52            43
# 1         2  2021-01-01 00:25:59   2021-01-01 00:34:44           166
# 2         2  2021-01-01 00:45:57   2021-01-01 00:51:55            41
# 3         2  2020-12-31 23:57:51   2021-01-01 00:04:56           168
# 7         2  2021-01-01 00:26:31   2021-01-01 00:28:50            75
#
#    DOLocationID  trip_distance  fare_amount  extra  mta_tax  tip_amount  \
# 0           151           1.01          5.5    0.5      0.5        0.00
# 1           239           2.53         10.0    0.5      0.5        2.81
# 2            42           1.12          6.0    0.5      0.5        1.00
# 3            75           1.99          8.0    0.5      0.5        0.00
# 7            75           0.45          3.5    0.5      0.5        0.96
#
#    tolls_amount  improvement_surcharge  total_amount  duration
# 0           0.0                    0.3          6.80  3.933333
# 1           0.0                    0.3         16.86  8.750000
# 2           0.0                    0.3          8.30  5.966667
# 3           0.0                    0.3          9.30  7.083333
# 7           0.0                    0.3          5.76  2.316667

# %%
df = df.reset_index()

# %%
xvars = ['PULocationID','DOLocationID','trip_distance','fare_amount','extra','mta_tax','tip_amount','tolls_amount','improvement_surcharge','total_amount']
yvars = ['duration']

# %%
Xtrain = df[xvars]
ytrain = df[yvars]

# %%
Xtrain
# Out:
#        PULocationID  DOLocationID  trip_distance  fare_amount  extra  mta_tax  \
# 0                43           151           1.01         5.50   0.50      0.5
# 1               166           239           2.53        10.00   0.50      0.5
# 2                41            42           1.12         6.00   0.50      0.5
# 3               168            75           1.99         8.00   0.50      0.5
# 4                75            75           0.45         3.50   0.50      0.5
# ...             ...           ...            ...          ...    ...      ...
# 73903            81            90          17.63        56.23   2.75      0.0
# 73904            35           213          18.36        46.66   0.00      0.0
# 73905            74            69           2.50        18.95   2.75      0.0
# 73906           168           215          14.48        48.87   2.75      0.0
# 73907           119           244           1.81        15.45   2.75      0.0
#
#        tip_amount  tolls_amount  improvement_surcharge  total_amount
# 0            0.00          0.00                    0.3          6.80
# 1            2.81          0.00                    0.3         16.86
# 2            1.00          0.00                    0.3          8.30
# 3            0.00          0.00                    0.3          9.30
# 4            0.96          0.00                    0.3          5.76
# ...           ...           ...                    ...           ...
# 73903        0.00          6.12                    0.3         65.40
# 73904       12.20          6.12                    0.3         65.28
# 73905        0.00          0.00                    0.3         22.00
# 73906        0.00          6.12                    0.3         58.04
# 73907        0.00          0.00                    0.3         18.50
#
# [73908 rows x 10 columns]

# %%
Xtrain.dtypes
# Out:
# PULocationID               int64
# DOLocationID               int64
# trip_distance            float64
# fare_amount              float64
# extra                    float64
# mta_tax                  float64
# tip_amount               float64
# tolls_amount             float64
# improvement_surcharge    float64
# total_amount             float64
# dtype: object

# %%
Xtrain.head()
# Out:
#    PULocationID  DOLocationID  trip_distance  fare_amount  extra  mta_tax  \
# 0            43           151           1.01          5.5    0.5      0.5
# 1           166           239           2.53         10.0    0.5      0.5
# 2            41            42           1.12          6.0    0.5      0.5
# 3           168            75           1.99          8.0    0.5      0.5
# 4            75            75           0.45          3.5    0.5      0.5
#
#    tip_amount  tolls_amount  improvement_surcharge  total_amount
# 0        0.00           0.0                    0.3          6.80
# 1        2.81           0.0                    0.3         16.86
# 2        1.00           0.0                    0.3          8.30
# 3        0.00           0.0                    0.3          9.30
# 4        0.96           0.0                    0.3          5.76

# %%
ytrain.head()
# Out:
#    duration
# 0  3.933333
# 1  8.750000
# 2  5.966667
# 3  7.083333
# 4  2.316667

# %%
X_train, X_test, y_train, y_test = train_test_split(Xtrain, ytrain, test_size=0.2, random_state=42)

# %%
DTrain = xgb.DMatrix(X_train.values, y_train.values)
DVal = xgb.DMatrix(X_test.values, y_test.values)

# %% [markdown]
# ## XGBoost

# %%
from hyperopt.pyll import scope

# %%
search_space = {
    "n_estimators": hp.choice("n_estimators", [10, 25, 50, 100, 200, 400]),
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42
}

# %%
def objective(params):
    with mlflow.start_run():
        
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        
        booster = xgb.train(
            params=params,
            dtrain=DTrain,
            num_boost_round=200,
            evals=[(DVal, 'validation')],
            early_stopping_rounds=50
        )
        
        y_pred = booster.predict(DVal)
        rmse = RMSE(y_test, y_pred)
        
        mlflow.log_metric("rmse", rmse)

    return {'loss': rmse, 'status': STATUS_OK}

# %% [markdown]
# ### 1. max_evals=50 means that Hyperopt will test 50 different sets of hyperparameters (not all combinations).
# ### 2. Hyperopt uses the Tree of Parzen Estimators (TPE) algorithm (in your case, specified with algo=tpe.suggest) to suggest the next set of hyperparameters based on past results, rather than exhaustively trying all combinations.

# %%
best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
)
# Out:
#   0%|          | 0/50 [00:00<?, ?trial/s, best loss=?]
# [0]	validation-rmse:10.91667
# [1]	validation-rmse:10.36193
# [2]	validation-rmse:9.85388
# [3]	validation-rmse:9.38929
# [4]	validation-rmse:8.96369
# [5]	validation-rmse:8.57492
# [6]	validation-rmse:8.22249
# [7]	validation-rmse:7.90294
# [8]	validation-rmse:7.61310
# [9]	validation-rmse:7.35144
# [10]	validation-rmse:7.11718
# [11]	validation-rmse:6.90632
# [12]	validation-rmse:6.71635
# [13]	validation-rmse:6.54859
# [14]	validation-rmse:6.39893
# [15]	validation-rmse:6.26608
# [16]	validation-rmse:6.14997
# [17]	validation-rmse:6.04756
# [18]	validation-rmse:5.95957
# [19]	validation-rmse:5.88223
# [20]	validation-rmse:5.81637
# [21]	validation-rmse:5.75887
# [22]	validation-rmse:5.71075
# [23]	validation-rmse:5.66831
# [24]	validation-rmse:5.63096
# [25]	validation-rmse:5.60027
# [26]	validation-rmse:5.57381
# [27]	validation-rmse:5.55101
# [28]	validation-rmse:5.53184
# [29]	validation-rmse:5.51558
# [30]	validation-rmse:5.50238
# [31]	validation-rmse:5.48872
# [32]	validation-rmse:5.48054
# [33]	validation-rmse:5.47302
# [34]	validation-rmse:5.46810
# [35]	validation-rmse:5.46330
# [36]	validation-rmse:5.45725
# [37]	validation-rmse:5.45243
# [38]	validation-rmse:5.44884
# [39]	validation-rmse:5.44637
# [40]	validation-rmse:5.44407
# [41]	validation-rmse:5.44160
# [42]	validation-rmse:5.44016
# [43]	validation-rmse:5.43902
# [44]	validation-rmse:5.43792
# [45]	validation-rmse:5.43626
# [46]	validation-rmse:5.43492
# [47]	validation-rmse:5.43399
# [48]	validation-rmse:5.43336
# [49]	validation-rmse:5.43287
# [50]	validation-rmse:5.43271
# [51]	validation-rmse:5.43276
# [52]	validation-rmse:5.43276
# [53]	validation-rmse:5.43289
# [54]	validation-rmse:5.43287
# [55]	validation-rmse:5.43295
# [56]	validation-rmse:5.43316
# [57]	validation-rmse:5.43349
# [58]	validation-rmse:5.43383
# [59]	validation-rmse:5.43417
# [60]	validation-rmse:5.43465
# [61]	validation-rmse:5.43505
# [62]	validation-rmse:5.43523
# [63]	validation-rmse:5.43564
# [64]	validation-rmse:5.43622
# [65]	validation-rmse:5.43664
# [66]	validation-rmse:5.43708
# [67]	validation-rmse:5.43735
# [68]	validation-rmse:5.43779
# [69]	validation-rmse:5.43811
# [70]	validation-rmse:5.43857
# [71]	validation-rmse:5.43908
# [72]	validation-rmse:5.43939
# [73]	validation-rmse:5.43987
# [74]	validation-rmse:5.44022
# [75]	validation-rmse:5.44056
# [76]	validation-rmse:5.44093
# [77]	validation-rmse:5.44116
# [78]	validation-rmse:5.44143
# [79]	validation-rmse:5.44168
# [80]	validation-rmse:5.44184
# [81]	validation-rmse:5.44210
# [82]	validation-rmse:5.44232
# [83]	validation-rmse:5.44248
# [84]	validation-rmse:5.44270
# [85]	validation-rmse:5.44288
# [86]	validation-rmse:5.44303
# [87]	validation-rmse:5.44324
# [88]	validation-rmse:5.44339
# [89]	validation-rmse:5.44356
# [90]	validation-rmse:5.44373
# [91]	validation-rmse:5.44384
# [92]	validation-rmse:5.44397
# [93]	validation-rmse:5.44407
# [94]	validation-rmse:5.44420
# [95]	validation-rmse:5.44430
# [96]	validation-rmse:5.44440
# [97]	validation-rmse:5.44448
# [98]	validation-rmse:5.44456
# [99]	validation-rmse:5.44463
# [0]	validation-rmse:9.08921
# [1]	validation-rmse:7.41346
# [2]	validation-rmse:6.28794
# [3]	validation-rmse:5.56132
# [4]	validation-rmse:5.10807
# [5]	validation-rmse:4.84445
# [6]	validation-rmse:4.68830
# [7]	validation-rmse:4.59279
# [8]	validation-rmse:4.54573
# [9]	validation-rmse:4.51018
# [10]	validation-rmse:4.49603
# [11]	validation-rmse:4.49141
# [12]	validation-rmse:4.49113
# [13]	validation-rmse:4.49226
# [14]	validation-rmse:4.49389
# [15]	validation-rmse:4.50261
# [16]	validation-rmse:4.50465
# [17]	validation-rmse:4.51416
# [18]	validation-rmse:4.51680
# [19]	validation-rmse:4.52015
# [20]	validation-rmse:4.52226
# [21]	validation-rmse:4.52150
# [22]	validation-rmse:4.52499
# [23]	validation-rmse:4.52919
# [24]	validation-rmse:4.53248
# [25]	validation-rmse:4.53732
# [26]	validation-rmse:4.54502
# [27]	validation-rmse:4.54630
# [28]	validation-rmse:4.55128
# [29]	validation-rmse:4.55299
# [30]	validation-rmse:4.55970
# [31]	validation-rmse:4.56193
# [32]	validation-rmse:4.56761
# [33]	validation-rmse:4.57171
# [34]	validation-rmse:4.57449
# [35]	validation-rmse:4.57753
# [36]	validation-rmse:4.58071
# [37]	validation-rmse:4.58336
# [38]	validation-rmse:4.58798
# [39]	validation-rmse:4.59293
# [40]	validation-rmse:4.59659
# [41]	validation-rmse:4.59900
# [42]	validation-rmse:4.60044
# [43]	validation-rmse:4.60360
# [44]	validation-rmse:4.60654
# [45]	validation-rmse:4.60781
# [46]	validation-rmse:4.61086
# [47]	validation-rmse:4.61386
# [48]	validation-rmse:4.61375
# [49]	validation-rmse:4.61546
# [50]	validation-rmse:4.61870
# [51]	validation-rmse:4.62124
# [52]	validation-rmse:4.62129
# [53]	validation-rmse:4.62402
# [54]	validation-rmse:4.62587
# [55]	validation-rmse:4.62838
# [56]	validation-rmse:4.63186
# [57]	validation-rmse:4.63250
# [58]	validation-rmse:4.63417
# [59]	validation-rmse:4.63494
# [60]	validation-rmse:4.63650
# [61]	validation-rmse:4.63911
# [62]	validation-rmse:4.64111
# [0]	validation-rmse:7.70058
# [1]	validation-rmse:5.92379
# [2]	validation-rmse:5.22583
# [3]	validation-rmse:4.97329
# [4]	validation-rmse:4.89778
# [5]	validation-rmse:4.88367
# [6]	validation-rmse:4.88623
# [7]	validation-rmse:4.90099
# [8]	validation-rmse:4.90793
# [9]	validation-rmse:4.91211
# [10]	validation-rmse:4.91688
# [11]	validation-rmse:4.91958
# [12]	validation-rmse:4.92306
# [13]	validation-rmse:4.92922
# [14]	validation-rmse:4.93286
# [15]	validation-rmse:4.93450
# [16]	validation-rmse:4.93493
# [17]	validation-rmse:4.93543
# [18]	validation-rmse:4.93790
# [19]	validation-rmse:4.94043
# [20]	validation-rmse:4.94071
# [21]	validation-rmse:4.94053
# [22]	validation-rmse:4.94161
# [23]	validation-rmse:4.94263
# [24]	validation-rmse:4.94262
# [25]	validation-rmse:4.94393
# [26]	validation-rmse:4.94589
# [27]	validation-rmse:4.94631
# [28]	validation-rmse:4.94681
# [29]	validation-rmse:4.94701
# [30]	validation-rmse:4.94909
# [31]	validation-rmse:4.94979
# [32]	validation-rmse:4.95131
# [33]	validation-rmse:4.95268
# [34]	validation-rmse:4.95311
# [35]	validation-rmse:4.95471
# [36]	validation-rmse:4.95560
# [37]	validation-rmse:4.95651
# [38]	validation-rmse:4.95710
# [39]	validation-rmse:4.95725
# [40]	validation-rmse:4.95779
# [41]	validation-rmse:4.95809
# [42]	validation-rmse:4.95849
# [43]	validation-rmse:4.95898
# [44]	validation-rmse:4.95916
# [45]	validation-rmse:4.95967
# [46]	validation-rmse:4.96018
# [47]	validation-rmse:4.96079
# [48]	validation-rmse:4.96104
# [49]	validation-rmse:4.96120
# [50]	validation-rmse:4.96145
# [51]	validation-rmse:4.96153
# [52]	validation-rmse:4.96176
# [53]	validation-rmse:4.96224
# [54]	validation-rmse:4.96248
# [0]	validation-rmse:9.04766
# [1]	validation-rmse:7.37197
# [2]	validation-rmse:6.26370
# [3]	validation-rmse:5.55562
# [4]	validation-rmse:5.13176
# [5]	validation-rmse:4.88802
# [6]	validation-rmse:4.75455
# [7]	validation-rmse:4.68361
# [8]	validation-rmse:4.64103
# [9]	validation-rmse:4.62247
# [10]	validation-rmse:4.61175
# [11]	validation-rmse:4.60490
# [12]	validation-rmse:4.60441
# [13]	validation-rmse:4.60316
# [14]	validation-rmse:4.60929
# [15]	validation-rmse:4.61433
# [16]	validation-rmse:4.61971
# [17]	validation-rmse:4.62789
# [18]	validation-rmse:4.62938
# [19]	validation-rmse:4.63012
# [20]	validation-rmse:4.63595
# [21]	validation-rmse:4.63662
# [22]	validation-rmse:4.63826
# [23]	validation-rmse:4.63588
# [24]	validation-rmse:4.63990
# [25]	validation-rmse:4.63876
# [26]	validation-rmse:4.64076
# [27]	validation-rmse:4.64272
# [28]	validation-rmse:4.64458
# [29]	validation-rmse:4.64584
# [30]	validation-rmse:4.64714
# [31]	validation-rmse:4.64910
# [32]	validation-rmse:4.64970
# [33]	validation-rmse:4.65168
# [34]	validation-rmse:4.65393
# [35]	validation-rmse:4.65588
# [36]	validation-rmse:4.65813
# [37]	validation-rmse:4.66132
# [38]	validation-rmse:4.66211
# [39]	validation-rmse:4.66259
# [40]	validation-rmse:4.66428
# [41]	validation-rmse:4.66528
# [42]	validation-rmse:4.66656
# [43]	validation-rmse:4.66814
# [44]	validation-rmse:4.66868
# [45]	validation-rmse:4.66989
# [46]	validation-rmse:4.67108
# [47]	validation-rmse:4.67449
# [48]	validation-rmse:4.67501
# [49]	validation-rmse:4.67619
# [50]	validation-rmse:4.67737
# [51]	validation-rmse:4.67793
# [52]	validation-rmse:4.67742
# [53]	validation-rmse:4.67851
# [54]	validation-rmse:4.67967
# [55]	validation-rmse:4.68118
# [56]	validation-rmse:4.68225
# [57]	validation-rmse:4.68362
# [58]	validation-rmse:4.68434
# [59]	validation-rmse:4.68479
# [60]	validation-rmse:4.68573
# [61]	validation-rmse:4.68684
# [62]	validation-rmse:4.68747
# [0]	validation-rmse:5.61146
# [1]	validation-rmse:5.21248
# [2]	validation-rmse:5.27513
# [3]	validation-rmse:5.32946
# [4]	validation-rmse:5.35754
# [5]	validation-rmse:5.36894
# [6]	validation-rmse:5.37142
# [7]	validation-rmse:5.37667
# [8]	validation-rmse:5.38535
# [9]	validation-rmse:5.39750
# [10]	validation-rmse:5.39875
# [11]	validation-rmse:5.39870
# [12]	validation-rmse:5.40153
# [13]	validation-rmse:5.41381
# [14]	validation-rmse:5.41561
# [15]	validation-rmse:5.41618
# [16]	validation-rmse:5.41810
# [17]	validation-rmse:5.41990
# [18]	validation-rmse:5.42205
# [19]	validation-rmse:5.42385
# [20]	validation-rmse:5.42463
# [21]	validation-rmse:5.42602
# [22]	validation-rmse:5.42761
# [23]	validation-rmse:5.42754
# [24]	validation-rmse:5.42824
# [25]	validation-rmse:5.42967
# [26]	validation-rmse:5.43029
# [27]	validation-rmse:5.43140
# [28]	validation-rmse:5.43189
# [29]	validation-rmse:5.43233
# [30]	validation-rmse:5.43272
# [31]	validation-rmse:5.43308
# [32]	validation-rmse:5.43363
# [33]	validation-rmse:5.43364
# [34]	validation-rmse:5.43358
# [35]	validation-rmse:5.43371
# [36]	validation-rmse:5.43395
# [37]	validation-rmse:5.43412
# [38]	validation-rmse:5.43443
# [39]	validation-rmse:5.43455
# [40]	validation-rmse:5.43481
# [41]	validation-rmse:5.43473
# [42]	validation-rmse:5.43480
# [43]	validation-rmse:5.43503
# [44]	validation-rmse:5.43512
# [45]	validation-rmse:5.43519
# [46]	validation-rmse:5.43521
# [47]	validation-rmse:5.43529
# [48]	validation-rmse:5.43525
# [49]	validation-rmse:5.43530
# [50]	validation-rmse:5.43534
# [51]	validation-rmse:5.43543
# [0]	validation-rmse:10.60055
# [1]	validation-rmse:9.78439
# [2]	validation-rmse:9.06091
# [3]	validation-rmse:8.42029
# [4]	validation-rmse:7.86260
# [5]	validation-rmse:7.37333
# [6]	validation-rmse:6.94198
# [7]	validation-rmse:6.56929
# [8]	validation-rmse:6.24422
# [9]	validation-rmse:5.96761
# [10]	validation-rmse:5.72812
# [11]	validation-rmse:5.52724
# [12]	validation-rmse:5.35777
# [13]	validation-rmse:5.21115
# [14]	validation-rmse:5.09442
# [15]	validation-rmse:4.99092
# [16]	validation-rmse:4.90726
# [17]	validation-rmse:4.83628
# [18]	validation-rmse:4.78007
# [19]	validation-rmse:4.72801
# [20]	validation-rmse:4.68762
# [21]	validation-rmse:4.65485
# [22]	validation-rmse:4.62973
# [23]	validation-rmse:4.61098
# [24]	validation-rmse:4.59439
# [25]	validation-rmse:4.58170
# [26]	validation-rmse:4.57214
# [27]	validation-rmse:4.56183
# [28]	validation-rmse:4.55427
# [29]	validation-rmse:4.54743
# [30]	validation-rmse:4.54150
# [31]	validation-rmse:4.53783
# [32]	validation-rmse:4.53605
# [33]	validation-rmse:4.53244
# [34]	validation-rmse:4.53094
# [35]	validation-rmse:4.52829
# [36]	validation-rmse:4.52834
# [37]	validation-rmse:4.52967
# [38]	validation-rmse:4.52989
# [39]	validation-rmse:4.53000
# [40]	validation-rmse:4.53167
# [41]	validation-rmse:4.53381
# [42]	validation-rmse:4.53556
# [43]	validation-rmse:4.53709
# [44]	validation-rmse:4.53656
# [45]	validation-rmse:4.53740
# [46]	validation-rmse:4.53888
# [47]	validation-rmse:4.53973
# [48]	validation-rmse:4.54124
# [49]	validation-rmse:4.54270
# [50]	validation-rmse:4.54327
# [51]	validation-rmse:4.54344
# [52]	validation-rmse:4.54718
# [53]	validation-rmse:4.54915
# [54]	validation-rmse:4.55206
# [55]	validation-rmse:4.55402
# [56]	validation-rmse:4.55405
# [57]	validation-rmse:4.55517
# [58]	validation-rmse:4.55683
# [59]	validation-rmse:4.55680
# [60]	validation-rmse:4.55730
# [61]	validation-rmse:4.55937
# [62]	validation-rmse:4.56035
# [63]	validation-rmse:4.56133
# [64]	validation-rmse:4.56254
# [65]	validation-rmse:4.56337
# [66]	validation-rmse:4.56402
# [67]	validation-rmse:4.56498
# [68]	validation-rmse:4.56562
# [69]	validation-rmse:4.56721
# [70]	validation-rmse:4.56945
# [71]	validation-rmse:4.57083
# [72]	validation-rmse:4.57100
# [73]	validation-rmse:4.57143
# [74]	validation-rmse:4.57219
# [75]	validation-rmse:4.57331
# [76]	validation-rmse:4.57404
# [77]	validation-rmse:4.57511
# [78]	validation-rmse:4.57671
# [79]	validation-rmse:4.57777
# [80]	validation-rmse:4.57816
# [81]	validation-rmse:4.57907
# [82]	validation-rmse:4.57945
# [83]	validation-rmse:4.58057
# [84]	validation-rmse:4.58161
# [0]	validation-rmse:9.27113
# [1]	validation-rmse:7.66399
# [2]	validation-rmse:6.54495
# [3]	validation-rmse:5.80041
# [4]	validation-rmse:5.30467
# [5]	validation-rmse:4.97972
# [6]	validation-rmse:4.76927
# [7]	validation-rmse:4.64556
# [8]	validation-rmse:4.56945
# [9]	validation-rmse:4.52659
# [10]	validation-rmse:4.49727
# [11]	validation-rmse:4.47780
# [12]	validation-rmse:4.46509
# [13]	validation-rmse:4.45610
# [14]	validation-rmse:4.44953
# [15]	validation-rmse:4.44454
# [16]	validation-rmse:4.44228
# [17]	validation-rmse:4.43841
# [18]	validation-rmse:4.42841
# [19]	validation-rmse:4.42516
# [20]	validation-rmse:4.41862
# [21]	validation-rmse:4.41785
# [22]	validation-rmse:4.41318
# [23]	validation-rmse:4.41021
# [24]	validation-rmse:4.41052
# [25]	validation-rmse:4.40796
# [26]	validation-rmse:4.40891
# [27]	validation-rmse:4.40108
# [28]	validation-rmse:4.40320
# [29]	validation-rmse:4.40260
# [30]	validation-rmse:4.39735
# [31]	validation-rmse:4.39625
# [32]	validation-rmse:4.39676
# [33]	validation-rmse:4.39636
# [34]	validation-rmse:4.39890
# [35]	validation-rmse:4.39802
# [36]	validation-rmse:4.39817
# [37]	validation-rmse:4.39720
# [38]	validation-rmse:4.39790
# [39]	validation-rmse:4.39817
# [40]	validation-rmse:4.40027
# [41]	validation-rmse:4.40118
# [42]	validation-rmse:4.39970
# [43]	validation-rmse:4.40014
# [44]	validation-rmse:4.40016
# [45]	validation-rmse:4.40200
# [46]	validation-rmse:4.40457
# [47]	validation-rmse:4.40265
# [48]	validation-rmse:4.40187
# [49]	validation-rmse:4.40327
# [50]	validation-rmse:4.40137
# [51]	validation-rmse:4.40045
# [52]	validation-rmse:4.40092
# [53]	validation-rmse:4.40045
# [54]	validation-rmse:4.40383
# [55]	validation-rmse:4.40336
# [56]	validation-rmse:4.40360
# [57]	validation-rmse:4.40194
# [58]	validation-rmse:4.40287
# [59]	validation-rmse:4.40312
# [60]	validation-rmse:4.40483
# [61]	validation-rmse:4.40432
# [62]	validation-rmse:4.40464
# [63]	validation-rmse:4.40740
# [64]	validation-rmse:4.40738
# [65]	validation-rmse:4.40984
# [66]	validation-rmse:4.40661
# [67]	validation-rmse:4.40809
# [68]	validation-rmse:4.40972
# [69]	validation-rmse:4.41037
# [70]	validation-rmse:4.41069
# [71]	validation-rmse:4.41117
# [72]	validation-rmse:4.41083
# [73]	validation-rmse:4.41122
# [74]	validation-rmse:4.41109
# [75]	validation-rmse:4.41188
# [76]	validation-rmse:4.41307
# [77]	validation-rmse:4.41250
# [78]	validation-rmse:4.41287
# [79]	validation-rmse:4.41392
# [80]	validation-rmse:4.41519
# [81]	validation-rmse:4.41564
# [0]	validation-rmse:6.89822
# [1]	validation-rmse:5.42626
# [2]	validation-rmse:5.09966
# [3]	validation-rmse:5.06305
# [4]	validation-rmse:5.08079
# [5]	validation-rmse:5.10074
# [6]	validation-rmse:5.10959
# [7]	validation-rmse:5.11252
# [8]	validation-rmse:5.12130
# [9]	validation-rmse:5.12702
# [10]	validation-rmse:5.13188
# [11]	validation-rmse:5.13624
# [12]	validation-rmse:5.13764
# [13]	validation-rmse:5.13893
# [14]	validation-rmse:5.14062
# [15]	validation-rmse:5.14206
# [16]	validation-rmse:5.14320
# [17]	validation-rmse:5.14390
# [18]	validation-rmse:5.14516
# [19]	validation-rmse:5.14520
# [20]	validation-rmse:5.14547
# [21]	validation-rmse:5.14562
# [22]	validation-rmse:5.14565
# [23]	validation-rmse:5.14596
# [24]	validation-rmse:5.14631
# [25]	validation-rmse:5.14662
# [26]	validation-rmse:5.14673
# [27]	validation-rmse:5.14697
# [28]	validation-rmse:5.14715
# [29]	validation-rmse:5.14728
# [30]	validation-rmse:5.14741
# [31]	validation-rmse:5.14757
# [32]	validation-rmse:5.14751
# [33]	validation-rmse:5.14760
# [34]	validation-rmse:5.14764
# [35]	validation-rmse:5.14776
# [36]	validation-rmse:5.14782
# [37]	validation-rmse:5.14786
# [38]	validation-rmse:5.14788
# [39]	validation-rmse:5.14792
# [40]	validation-rmse:5.14798
# [41]	validation-rmse:5.14799
# [42]	validation-rmse:5.14805
# [43]	validation-rmse:5.14808
# [44]	validation-rmse:5.14812
# [45]	validation-rmse:5.14813
# [46]	validation-rmse:5.14815
# [47]	validation-rmse:5.14814
# [48]	validation-rmse:5.14816
# [49]	validation-rmse:5.14817
# [50]	validation-rmse:5.14817
# [51]	validation-rmse:5.14818
# [52]	validation-rmse:5.14818
# [53]	validation-rmse:5.14819
# [0]	validation-rmse:11.01319
# [1]	validation-rmse:10.53844
# [2]	validation-rmse:10.09144
# [3]	validation-rmse:9.67430
# [4]	validation-rmse:9.28297
# [5]	validation-rmse:8.91647
# [6]	validation-rmse:8.57504
# [7]	validation-rmse:8.25475
# [8]	validation-rmse:7.95646
# [9]	validation-rmse:7.67942
# [10]	validation-rmse:7.42044
# [11]	validation-rmse:7.17980
# [12]	validation-rmse:6.95649
# [13]	validation-rmse:6.75035
# [14]	validation-rmse:6.55661
# [15]	validation-rmse:6.37710
# [16]	validation-rmse:6.21238
# [17]	validation-rmse:6.05979
# [18]	validation-rmse:5.91975
# [19]	validation-rmse:5.78929
# [20]	validation-rmse:5.66838
# [21]	validation-rmse:5.55680
# [22]	validation-rmse:5.45444
# [23]	validation-rmse:5.36140
# [24]	validation-rmse:5.27534
# [25]	validation-rmse:5.19551
# [26]	validation-rmse:5.12456
# [27]	validation-rmse:5.05923
# [28]	validation-rmse:5.00085
# [29]	validation-rmse:4.94665
# [30]	validation-rmse:4.89673
# [31]	validation-rmse:4.85206
# [32]	validation-rmse:4.81044
# [33]	validation-rmse:4.77338
# [34]	validation-rmse:4.74061
# [35]	validation-rmse:4.71069
# [36]	validation-rmse:4.68467
# [37]	validation-rmse:4.66111
# [38]	validation-rmse:4.63939
# [39]	validation-rmse:4.61973
# [40]	validation-rmse:4.60148
# [41]	validation-rmse:4.58470
# [42]	validation-rmse:4.57050
# [43]	validation-rmse:4.55740
# [44]	validation-rmse:4.54458
# [45]	validation-rmse:4.53414
# [46]	validation-rmse:4.52446
# [47]	validation-rmse:4.51411
# [48]	validation-rmse:4.50576
# [49]	validation-rmse:4.49879
# [50]	validation-rmse:4.49312
# [51]	validation-rmse:4.48734
# [52]	validation-rmse:4.48174
# [53]	validation-rmse:4.47719
# [54]	validation-rmse:4.47133
# [55]	validation-rmse:4.46743
# [56]	validation-rmse:4.46311
# [57]	validation-rmse:4.45854
# [58]	validation-rmse:4.45606
# [59]	validation-rmse:4.45207
# [60]	validation-rmse:4.44883
# [61]	validation-rmse:4.44623
# [62]	validation-rmse:4.44448
# [63]	validation-rmse:4.44340
# [64]	validation-rmse:4.44138
# [65]	validation-rmse:4.44022
# [66]	validation-rmse:4.43838
# [67]	validation-rmse:4.43800
# [68]	validation-rmse:4.43649
# [69]	validation-rmse:4.43599
# [70]	validation-rmse:4.43514
# [71]	validation-rmse:4.43499
# [72]	validation-rmse:4.43449
# [73]	validation-rmse:4.43341
# [74]	validation-rmse:4.43212
# [75]	validation-rmse:4.43183
# ...
# [4]	validation-rmse:8.22158
# [5]	validation-rmse:7.76490
# [6]	validation-rmse:7.35384
# [7]	validation-rmse:6.99729
# [8]	validation-rmse:6.68259
# [9]	validation-rmse:6.40298
# [10]	validation-rmse:6.15830
# [11]	validation-rmse:5.94270
# [12]	validation-rmse:5.75669
# [13]	validation-rmse:5.59021
# [14]	validation-rmse:5.45148
# [15]	validation-rmse:5.32969
# [16]	validation-rmse:5.22658
# [17]	validation-rmse:5.13783
# [18]	validation-rmse:5.06044
# [19]	validation-rmse:4.99054
# [20]	validation-rmse:4.93163
# [21]	validation-rmse:4.88045
# [22]	validation-rmse:4.83534
# [23]	validation-rmse:4.79468
# [24]	validation-rmse:4.76157
# [25]	validation-rmse:4.73336
# [26]	validation-rmse:4.70484
# [27]	validation-rmse:4.68074
# [28]	validation-rmse:4.65989
# [29]	validation-rmse:4.64095
# [30]	validation-rmse:4.62347
# [31]	validation-rmse:4.60984
# [32]	validation-rmse:4.59496
# [33]	validation-rmse:4.58085
# [34]	validation-rmse:4.57155
# [35]	validation-rmse:4.56179
# [36]	validation-rmse:4.55360
# [37]	validation-rmse:4.54642
# [38]	validation-rmse:4.53361
# [39]	validation-rmse:4.52587
# [40]	validation-rmse:4.51924
# [41]	validation-rmse:4.51363
# [42]	validation-rmse:4.50797
# [43]	validation-rmse:4.49978
# [44]	validation-rmse:4.49321
# [45]	validation-rmse:4.48891
# [46]	validation-rmse:4.48345
# [47]	validation-rmse:4.47806
# [48]	validation-rmse:4.47397
# [49]	validation-rmse:4.46959
# [50]	validation-rmse:4.46485
# [51]	validation-rmse:4.46345
# [52]	validation-rmse:4.45616
# [53]	validation-rmse:4.45414
# [54]	validation-rmse:4.45008
# [55]	validation-rmse:4.44632
# [56]	validation-rmse:4.44171
# [57]	validation-rmse:4.44061
# [58]	validation-rmse:4.43765
# [59]	validation-rmse:4.43587
# [60]	validation-rmse:4.43422
# [61]	validation-rmse:4.43298
# [62]	validation-rmse:4.43187
# [63]	validation-rmse:4.43085
# [64]	validation-rmse:4.42740
# [65]	validation-rmse:4.42576
# [66]	validation-rmse:4.42357
# [67]	validation-rmse:4.42076
# [68]	validation-rmse:4.41696
# [69]	validation-rmse:4.41474
# [70]	validation-rmse:4.41217
# [71]	validation-rmse:4.41063
# [72]	validation-rmse:4.40915
# [73]	validation-rmse:4.40842
# [74]	validation-rmse:4.40706
# [75]	validation-rmse:4.40494
# [76]	validation-rmse:4.39926
# [77]	validation-rmse:4.39718
# [78]	validation-rmse:4.39572
# [79]	validation-rmse:4.39418
# [80]	validation-rmse:4.39336
# [81]	validation-rmse:4.39098
# [82]	validation-rmse:4.39029
# [83]	validation-rmse:4.38898
# [84]	validation-rmse:4.38683
# [85]	validation-rmse:4.38584
# [86]	validation-rmse:4.38444
# [87]	validation-rmse:4.38105
# [88]	validation-rmse:4.37991
# [89]	validation-rmse:4.37689
# [90]	validation-rmse:4.37436
# [91]	validation-rmse:4.37165
# [92]	validation-rmse:4.37068
# [93]	validation-rmse:4.36970
# [94]	validation-rmse:4.36916
# [95]	validation-rmse:4.36856
# [96]	validation-rmse:4.36665
# [97]	validation-rmse:4.36453
# [98]	validation-rmse:4.36390
# [99]	validation-rmse:4.36457
# [100]	validation-rmse:4.36499
# [101]	validation-rmse:4.36479
# [102]	validation-rmse:4.36205
# [103]	validation-rmse:4.35959
# [104]	validation-rmse:4.35934
# [105]	validation-rmse:4.35800
# [106]	validation-rmse:4.35763
# [107]	validation-rmse:4.35766
# [108]	validation-rmse:4.35599
# [109]	validation-rmse:4.35400
# [110]	validation-rmse:4.35004
# [111]	validation-rmse:4.34885
# [112]	validation-rmse:4.34874
# [113]	validation-rmse:4.34721
# [114]	validation-rmse:4.34730
# [115]	validation-rmse:4.34668
# [116]	validation-rmse:4.34634
# [117]	validation-rmse:4.34561
# [118]	validation-rmse:4.34526
# [119]	validation-rmse:4.34432
# [120]	validation-rmse:4.34143
# [121]	validation-rmse:4.33909
# [122]	validation-rmse:4.33914
# [123]	validation-rmse:4.33809
# [124]	validation-rmse:4.33673
# [125]	validation-rmse:4.33429
# [126]	validation-rmse:4.33280
# [127]	validation-rmse:4.33195
# [128]	validation-rmse:4.33200
# [129]	validation-rmse:4.33051
# [130]	validation-rmse:4.33041
# [131]	validation-rmse:4.33001
# [132]	validation-rmse:4.33046
# [133]	validation-rmse:4.32941
# [134]	validation-rmse:4.32825
# [135]	validation-rmse:4.32588
# [136]	validation-rmse:4.32579
# [137]	validation-rmse:4.32570
# [138]	validation-rmse:4.32504
# [139]	validation-rmse:4.32497
# [140]	validation-rmse:4.32437
# [141]	validation-rmse:4.32487
# [142]	validation-rmse:4.32303
# [143]	validation-rmse:4.32237
# [144]	validation-rmse:4.32236
# [145]	validation-rmse:4.32152
# [146]	validation-rmse:4.32122
# [147]	validation-rmse:4.32118
# [148]	validation-rmse:4.31938
# [149]	validation-rmse:4.31814
# [150]	validation-rmse:4.31636
# [151]	validation-rmse:4.31516
# [152]	validation-rmse:4.31390
# [153]	validation-rmse:4.31424
# [154]	validation-rmse:4.31283
# [155]	validation-rmse:4.31083
# [156]	validation-rmse:4.31027
# [157]	validation-rmse:4.30854
# [158]	validation-rmse:4.30833
# [159]	validation-rmse:4.30672
# [160]	validation-rmse:4.30678
# [161]	validation-rmse:4.30540
# [162]	validation-rmse:4.30524
# [163]	validation-rmse:4.30447
# [164]	validation-rmse:4.30383
# [165]	validation-rmse:4.30295
# [166]	validation-rmse:4.30321
# [167]	validation-rmse:4.30300
# [168]	validation-rmse:4.30314
# [169]	validation-rmse:4.30327
# [170]	validation-rmse:4.30265
# [171]	validation-rmse:4.30132
# [172]	validation-rmse:4.30139
# [173]	validation-rmse:4.30151
# [174]	validation-rmse:4.30007
# [175]	validation-rmse:4.29999
# [176]	validation-rmse:4.30012
# [177]	validation-rmse:4.29886
# [178]	validation-rmse:4.29909
# [179]	validation-rmse:4.29913
# [180]	validation-rmse:4.29820
# [181]	validation-rmse:4.29807
# [182]	validation-rmse:4.29695
# [183]	validation-rmse:4.29676
# [184]	validation-rmse:4.29603
# [185]	validation-rmse:4.29590
# [186]	validation-rmse:4.29576
# [187]	validation-rmse:4.29569
# [188]	validation-rmse:4.29569
# [189]	validation-rmse:4.29583
# [190]	validation-rmse:4.29511
# [191]	validation-rmse:4.29446
# [192]	validation-rmse:4.29497
# [193]	validation-rmse:4.29451
# [194]	validation-rmse:4.29482
# [195]	validation-rmse:4.29471
# [196]	validation-rmse:4.29458
# [197]	validation-rmse:4.29153
# [198]	validation-rmse:4.29081
# [199]	validation-rmse:4.29081
# 100%|██████████| 50/50 [08:08<00:00,  9.77s/trial, best loss: 4.256112110630954]

# %%
best_params = best_result.copy()

best_params
# Out:
# {'learning_rate': np.float64(0.13976468928124036),
#  'max_depth': np.float64(9.0),
#  'min_child_weight': np.float64(17.967984695367992),
#  'n_estimators': np.int64(5),
#  'reg_alpha': np.float64(0.00868662437180616),
#  'reg_lambda': np.float64(0.33298214989501085)}

# %%
params = {
    'learning_rate': 0.13976468928124036,
    'max_depth': 9,
    'min_child_weight': 17.967984695367992,
    'n_estimators': 400,
    'objective': 'reg:linear',
    'reg_alpha': 0.00868662437180616,
    'reg_lambda': 0.33298214989501085,
    'seed': 42
}

mlflow.xgboost.autolog()

booster = xgb.train(
            params=params,
            dtrain=DTrain,
            num_boost_round=500,
            evals=[(DVal, 'validation')],
            early_stopping_rounds=50
        )
# Out:
# 2024/10/02 14:01:45 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '1e47ba5ec0c24556a68a7ad10589c53f', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# [0]	validation-rmse:10.21236
# [1]	validation-rmse:9.12551
# [2]	validation-rmse:8.21908
# [3]	validation-rmse:7.47825
# [4]	validation-rmse:6.86547
# [5]	validation-rmse:6.37392
# [6]	validation-rmse:5.98206
# [7]	validation-rmse:5.67285
# [8]	validation-rmse:5.41885
# [9]	validation-rmse:5.21701
# [10]	validation-rmse:5.06709
# [11]	validation-rmse:4.94891
# [12]	validation-rmse:4.84645
# [13]	validation-rmse:4.77415
# [14]	validation-rmse:4.72001
# [15]	validation-rmse:4.66887
# [16]	validation-rmse:4.63405
# [17]	validation-rmse:4.60117
# [18]	validation-rmse:4.57532
# [19]	validation-rmse:4.55763
# [20]	validation-rmse:4.53806
# [21]	validation-rmse:4.52216
# [22]	validation-rmse:4.50865
# [23]	validation-rmse:4.49301
# [24]	validation-rmse:4.48568
# [25]	validation-rmse:4.47089
# [26]	validation-rmse:4.46228
# [27]	validation-rmse:4.45677
# [28]	validation-rmse:4.45060
# [29]	validation-rmse:4.44458
# [30]	validation-rmse:4.43960
# [31]	validation-rmse:4.43195
# [32]	validation-rmse:4.42562
# [33]	validation-rmse:4.42197
# [34]	validation-rmse:4.41785
# [35]	validation-rmse:4.41137
# [36]	validation-rmse:4.40718
# [37]	validation-rmse:4.39986
# [38]	validation-rmse:4.40060
# [39]	validation-rmse:4.39895
# [40]	validation-rmse:4.39822
# [41]	validation-rmse:4.39541
# [42]	validation-rmse:4.38804
# [43]	validation-rmse:4.38748
# [44]	validation-rmse:4.38551
# [45]	validation-rmse:4.37769
# [46]	validation-rmse:4.37143
# [47]	validation-rmse:4.36929
# [48]	validation-rmse:4.36448
# [49]	validation-rmse:4.36138
# [50]	validation-rmse:4.35932
# [51]	validation-rmse:4.35499
# [52]	validation-rmse:4.35117
# [53]	validation-rmse:4.34865
# [54]	validation-rmse:4.34694
# [55]	validation-rmse:4.34146
# [56]	validation-rmse:4.33857
# [57]	validation-rmse:4.33740
# [58]	validation-rmse:4.33691
# [59]	validation-rmse:4.33516
# [60]	validation-rmse:4.33512
# [61]	validation-rmse:4.33437
# [62]	validation-rmse:4.33302
# [63]	validation-rmse:4.33259
# [64]	validation-rmse:4.33058
# [65]	validation-rmse:4.32863
# [66]	validation-rmse:4.32698
# [67]	validation-rmse:4.32445
# [68]	validation-rmse:4.32528
# [69]	validation-rmse:4.32474
# [70]	validation-rmse:4.32096
# [71]	validation-rmse:4.31766
# [72]	validation-rmse:4.31740
# [73]	validation-rmse:4.31494
# [74]	validation-rmse:4.31524
# [75]	validation-rmse:4.31516
# [76]	validation-rmse:4.31452
# [77]	validation-rmse:4.31463
# [78]	validation-rmse:4.31418
# [79]	validation-rmse:4.31097
# [80]	validation-rmse:4.30756
# [81]	validation-rmse:4.30292
# [82]	validation-rmse:4.30269
# [83]	validation-rmse:4.30341
# [84]	validation-rmse:4.30276
# [85]	validation-rmse:4.30192
# [86]	validation-rmse:4.30146
# [87]	validation-rmse:4.29827
# [88]	validation-rmse:4.29713
# [89]	validation-rmse:4.29642
# [90]	validation-rmse:4.29456
# [91]	validation-rmse:4.29412
# [92]	validation-rmse:4.29417
# [93]	validation-rmse:4.29137
# [94]	validation-rmse:4.29145
# [95]	validation-rmse:4.29021
# [96]	validation-rmse:4.29110
# [97]	validation-rmse:4.29148
# [98]	validation-rmse:4.29199
# [99]	validation-rmse:4.29248
# [100]	validation-rmse:4.29208
# [101]	validation-rmse:4.29134
# [102]	validation-rmse:4.29101
# [103]	validation-rmse:4.29067
# [104]	validation-rmse:4.29007
# [105]	validation-rmse:4.28758
# [106]	validation-rmse:4.28711
# [107]	validation-rmse:4.28572
# [108]	validation-rmse:4.28574
# [109]	validation-rmse:4.28599
# [110]	validation-rmse:4.28576
# [111]	validation-rmse:4.28604
# [112]	validation-rmse:4.28636
# [113]	validation-rmse:4.28557
# [114]	validation-rmse:4.28581
# [115]	validation-rmse:4.28682
# [116]	validation-rmse:4.28670
# [117]	validation-rmse:4.28657
# [118]	validation-rmse:4.28580
# [119]	validation-rmse:4.28356
# [120]	validation-rmse:4.28421
# [121]	validation-rmse:4.28331
# [122]	validation-rmse:4.28192
# [123]	validation-rmse:4.28165
# [124]	validation-rmse:4.28075
# [125]	validation-rmse:4.28092
# [126]	validation-rmse:4.28007
# [127]	validation-rmse:4.28007
# [128]	validation-rmse:4.27844
# [129]	validation-rmse:4.27753
# [130]	validation-rmse:4.27494
# [131]	validation-rmse:4.27416
# [132]	validation-rmse:4.27451
# [133]	validation-rmse:4.27433
# [134]	validation-rmse:4.27305
# [135]	validation-rmse:4.27129
# [136]	validation-rmse:4.27041
# [137]	validation-rmse:4.26957
# [138]	validation-rmse:4.26897
# [139]	validation-rmse:4.26819
# [140]	validation-rmse:4.26739
# [141]	validation-rmse:4.26520
# [142]	validation-rmse:4.26440
# [143]	validation-rmse:4.26420
# [144]	validation-rmse:4.26434
# [145]	validation-rmse:4.26438
# [146]	validation-rmse:4.26432
# [147]	validation-rmse:4.26413
# [148]	validation-rmse:4.26426
# [149]	validation-rmse:4.26368
# [150]	validation-rmse:4.26396
# [151]	validation-rmse:4.26413
# [152]	validation-rmse:4.26384
# [153]	validation-rmse:4.26355
# [154]	validation-rmse:4.26292
# [155]	validation-rmse:4.26392
# [156]	validation-rmse:4.26353
# [157]	validation-rmse:4.26442
# [158]	validation-rmse:4.26372
# [159]	validation-rmse:4.26337
# [160]	validation-rmse:4.26338
# [161]	validation-rmse:4.26327
# [162]	validation-rmse:4.26351
# [163]	validation-rmse:4.26316
# [164]	validation-rmse:4.26324
# [165]	validation-rmse:4.26339
# [166]	validation-rmse:4.26423
# [167]	validation-rmse:4.26327
# [168]	validation-rmse:4.26183
# [169]	validation-rmse:4.26254
# [170]	validation-rmse:4.26325
# [171]	validation-rmse:4.26296
# [172]	validation-rmse:4.26278
# [173]	validation-rmse:4.26387
# [174]	validation-rmse:4.26212
# [175]	validation-rmse:4.26218
# [176]	validation-rmse:4.26201
# [177]	validation-rmse:4.26193
# [178]	validation-rmse:4.26224
# [179]	validation-rmse:4.26181
# [180]	validation-rmse:4.26063
# [181]	validation-rmse:4.26090
# [182]	validation-rmse:4.25916
# [183]	validation-rmse:4.25974
# [184]	validation-rmse:4.25993
# [185]	validation-rmse:4.25829
# [186]	validation-rmse:4.25723
# [187]	validation-rmse:4.25758
# [188]	validation-rmse:4.25745
# [189]	validation-rmse:4.25808
# [190]	validation-rmse:4.25796
# [191]	validation-rmse:4.25792
# [192]	validation-rmse:4.25865
# [193]	validation-rmse:4.25835
# [194]	validation-rmse:4.25847
# [195]	validation-rmse:4.25730
# [196]	validation-rmse:4.25702
# [197]	validation-rmse:4.25657
# [198]	validation-rmse:4.25668
# [199]	validation-rmse:4.25611
# [200]	validation-rmse:4.25690
# [201]	validation-rmse:4.25602
# [202]	validation-rmse:4.25597
# [203]	validation-rmse:4.25509
# [204]	validation-rmse:4.25529
# [205]	validation-rmse:4.25368
# [206]	validation-rmse:4.25420
# [207]	validation-rmse:4.25363
# [208]	validation-rmse:4.25366
# [209]	validation-rmse:4.25370
# [210]	validation-rmse:4.25387
# [211]	validation-rmse:4.25323
# [212]	validation-rmse:4.25316
# [213]	validation-rmse:4.25358
# [214]	validation-rmse:4.25338
# [215]	validation-rmse:4.25345
# [216]	validation-rmse:4.25279
# [217]	validation-rmse:4.25281
# [218]	validation-rmse:4.25288
# [219]	validation-rmse:4.25361
# [220]	validation-rmse:4.25274
# [221]	validation-rmse:4.25265
# [222]	validation-rmse:4.25201
# [223]	validation-rmse:4.25253
# [224]	validation-rmse:4.25268
# [225]	validation-rmse:4.25246
# [226]	validation-rmse:4.25197
# [227]	validation-rmse:4.25178
# [228]	validation-rmse:4.25186
# [229]	validation-rmse:4.25204
# [230]	validation-rmse:4.25242
# [231]	validation-rmse:4.25215
# [232]	validation-rmse:4.25207
# [233]	validation-rmse:4.25159
# [234]	validation-rmse:4.25177
# [235]	validation-rmse:4.25146
# [236]	validation-rmse:4.25159
# [237]	validation-rmse:4.25174
# [238]	validation-rmse:4.25064
# [239]	validation-rmse:4.25051
# [240]	validation-rmse:4.25122
# [241]	validation-rmse:4.25224
# [242]	validation-rmse:4.25245
# [243]	validation-rmse:4.25279
# [244]	validation-rmse:4.25348
# [245]	validation-rmse:4.25396
# [246]	validation-rmse:4.25430
# [247]	validation-rmse:4.25449
# [248]	validation-rmse:4.25434
# [249]	validation-rmse:4.25398
# [250]	validation-rmse:4.25451
# [251]	validation-rmse:4.25516
# [252]	validation-rmse:4.25523
# [253]	validation-rmse:4.25556
# [254]	validation-rmse:4.25536
# [255]	validation-rmse:4.25531
# [256]	validation-rmse:4.25559
# [257]	validation-rmse:4.25580
# [258]	validation-rmse:4.25563
# [259]	validation-rmse:4.25553
# [260]	validation-rmse:4.25545
# [261]	validation-rmse:4.25543
# [262]	validation-rmse:4.25505
# [263]	validation-rmse:4.25443
# [264]	validation-rmse:4.25472
# [265]	validation-rmse:4.25454
# [266]	validation-rmse:4.25416
# [267]	validation-rmse:4.25380
# [268]	validation-rmse:4.25374
# [269]	validation-rmse:4.25398
# [270]	validation-rmse:4.25403
# [271]	validation-rmse:4.25365
# [272]	validation-rmse:4.25370
# [273]	validation-rmse:4.25354
# [274]	validation-rmse:4.25407
# [275]	validation-rmse:4.25505
# [276]	validation-rmse:4.25510
# [277]	validation-rmse:4.25582
# [278]	validation-rmse:4.25622
# [279]	validation-rmse:4.25607
# [280]	validation-rmse:4.25653
# [281]	validation-rmse:4.25740
# [282]	validation-rmse:4.25725
# [283]	validation-rmse:4.25691
# [284]	validation-rmse:4.25649
# [285]	validation-rmse:4.25747
# [286]	validation-rmse:4.25746
# [287]	validation-rmse:4.25810
# [288]	validation-rmse:4.25801
# 2024/10/02 14:01:49 WARNING mlflow.xgboost: Failed to infer model signature: could not sample data to infer model signature: please ensure that autologging is enabled before constructing the dataset.
# 2024/10/02 14:01:53 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.

# %%
from sklearn.metrics import r2_score
# Out:
# R-squared: 0.8633927702903748

# %%
logged_model = '/workspaces/MLOps/01-intro/mlruns/2/1e47ba5ec0c24556a68a7ad10589c53f/artifacts/model'

# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(logged_model)

# Predict on a Pandas DataFrame.
pred = loaded_model.predict(X_test)

r2 = r2_score(y_test, pred)

print(f"R-squared: {r2}")

sns.distplot(y_test,kde=True,label='actual')
sns.distplot(pred,kde=True,label='pred')
plt.legend()
# Out:
# R-squared: 0.8633927702903748
